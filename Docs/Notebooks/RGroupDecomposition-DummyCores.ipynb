# %% [markdown]
# This example shows how dummy cores will expand into new cores in the output.

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG=True
from rdkit.Chem import rdRGroupDecomposition
# Out:
# /Users/kellebr5/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: RuntimeWarning: to-Python converter for std::vector<boost::shared_ptr<RDKit::ROMol>, std::allocator<boost::shared_ptr<RDKit::ROMol> > > already registered; second conversion method ignored.

# %%
from rdkit.Chem import PandasTools

# %%
import pandas as pd
from rdkit.Chem import PandasTools

# %%
core = Chem.MolFromSmarts("*1****1-*2***2")

# %%
core

# %%
smiles = ["C1CCCC1-C2CCC2Cl", "N1CCCC1-C2CCC2Cl", "O1CCCC1-C2CCC2Cl", "N1OCCC1-C2CCC2Cl", "N1OCSC1-C2CCC2Cl"]

mols = [Chem.MolFromSmiles(smi) for smi in smiles]

# %%
from rdkit.Chem import Draw
Draw.MolsToGridImage(mols)

# %% [markdown]
# Make the RGroup decomposition!

# %%
rgroups = rdRGroupDecomposition.RGroupDecomposition(core)

# %%
for i,m in enumerate(mols):
    rgroups.Add(m)
    if i == 10:
        break

# %% [markdown]
# To finalize the rgroups, we need to call process after all molecules are added.

# %%
rgroups.Process()
# Out:
# True

# %%
groups = rgroups.GetRGroupsAsColumns()
frame = pd.DataFrame(groups)
PandasTools.ChangeMoleculeRendering(frame)

# %% [markdown]
# The dummy cores are expanding into the cores found during the decomposition.

# %%
frame
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Core                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     R1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 0                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>
# 1                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 2                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 3                                                              <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 4  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       None
